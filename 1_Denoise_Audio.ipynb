# %%
# 📦 Imports and Setup
import os
import torch
import torchaudio
from dccrn_model import DCCRN  # Make sure dccrn_model.py is in the same folder
import IPython.display as ipd
import numpy as np

# 🔧 Config
sample_rate = 48000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 📁 Paths
base_dir = os.getcwd()
noisy_dir = os.path.join(base_dir, "dataset", "noisy")
output_dir = os.path.join(base_dir, "output")
model_path = os.path.join(base_dir, "dccrn_final.pth")
os.makedirs(output_dir, exist_ok=True)

# ✅ Load model
model = DCCRN(
    rnn_layers=2,
    rnn_units=256,
    masking_mode='E',
    use_clstm=True,
    use_cbn=False,
    kernel_num=[32, 64, 128, 256, 256, 256]
).to(device)

state_dict = torch.load(model_path, map_location=device)
model.load_state_dict(state_dict)
model.eval()
print("✅ Model loaded successfully")
# Out:
# ======================================== Model Structures ========================================
# DCCRN(
#   (stft): ConvSTFT()
#   (istft): ConviSTFT()
#   (encoder): ModuleList(
#     (0): Sequential(
#       (0): ComplexConv2d(
#         (real_conv): Conv2d(1, 16, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#         (imag_conv): Conv2d(1, 16, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#       )
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (1): Sequential(
#       (0): ComplexConv2d(
#         (real_conv): Conv2d(16, 32, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#         (imag_conv): Conv2d(16, 32, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#       )
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (2): Sequential(
#       (0): ComplexConv2d(
#         (real_conv): Conv2d(32, 64, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#         (imag_conv): Conv2d(32, 64, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#       )
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (3): Sequential(
#       (0): ComplexConv2d(
#         (real_conv): Conv2d(64, 128, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#         (imag_conv): Conv2d(64, 128, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#       )
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (4-5): 2 x Sequential(
#       (0): ComplexConv2d(
#         (real_conv): Conv2d(128, 128, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#         (imag_conv): Conv2d(128, 128, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0))
#       )
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#   )
#   (decoder): ModuleList(
#     (0-1): 2 x Sequential(
#       (0): ComplexConvTranspose2d(
#         (real_conv): ConvTranspose2d(256, 128, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#         (imag_conv): ConvTranspose2d(256, 128, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#       )
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (2): Sequential(
#       (0): ComplexConvTranspose2d(
#         (real_conv): ConvTranspose2d(256, 64, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#         (imag_conv): ConvTranspose2d(256, 64, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#       )
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (3): Sequential(
#       (0): ComplexConvTranspose2d(
#         (real_conv): ConvTranspose2d(128, 32, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#         (imag_conv): ConvTranspose2d(128, 32, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#       )
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (4): Sequential(
#       (0): ComplexConvTranspose2d(
#         (real_conv): ConvTranspose2d(64, 16, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#         (imag_conv): ConvTranspose2d(64, 16, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#       )
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (5): Sequential(
#       (0): ComplexConvTranspose2d(
#         (real_conv): ConvTranspose2d(32, 1, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#         (imag_conv): ConvTranspose2d(32, 1, kernel_size=(5, 2), stride=(2, 1), padding=(2, 0), output_padding=(1, 0))
#       )
#     )
#   )
#   (enhance): Sequential(
#     (0): NavieComplexLSTM(
#       (real_lstm): LSTM(1536, 128)
#       (imag_lstm): LSTM(1536, 128)
#     )
#     (1): NavieComplexLSTM(
#       (real_lstm): LSTM(128, 128)
#       (imag_lstm): LSTM(128, 128)
#       (r_trans): Linear(in_features=128, out_features=1536, bias=True)
#       (i_trans): Linear(in_features=128, out_features=1536, bias=True)
#     )
#   )
# )
# ==================================================================================================
# ======================================== Model Parameters ========================================
# encoder.0.0.real_conv.weight torch.Size([16, 1, 5, 2])
# encoder.0.0.real_conv.bias torch.Size([16])
# encoder.0.0.imag_conv.weight torch.Size([16, 1, 5, 2])
# encoder.0.0.imag_conv.bias torch.Size([16])
# encoder.0.1.weight torch.Size([32])
# encoder.0.1.bias torch.Size([32])
# encoder.0.2.weight torch.Size([1])
# encoder.1.0.real_conv.weight torch.Size([32, 16, 5, 2])
# encoder.1.0.real_conv.bias torch.Size([32])
# encoder.1.0.imag_conv.weight torch.Size([32, 16, 5, 2])
# encoder.1.0.imag_conv.bias torch.Size([32])
# encoder.1.1.weight torch.Size([64])
# encoder.1.1.bias torch.Size([64])
# encoder.1.2.weight torch.Size([1])
# encoder.2.0.real_conv.weight torch.Size([64, 32, 5, 2])
# encoder.2.0.real_conv.bias torch.Size([64])
# encoder.2.0.imag_conv.weight torch.Size([64, 32, 5, 2])
# encoder.2.0.imag_conv.bias torch.Size([64])
# encoder.2.1.weight torch.Size([128])
# encoder.2.1.bias torch.Size([128])
# encoder.2.2.weight torch.Size([1])
# encoder.3.0.real_conv.weight torch.Size([128, 64, 5, 2])
# encoder.3.0.real_conv.bias torch.Size([128])
# encoder.3.0.imag_conv.weight torch.Size([128, 64, 5, 2])
# encoder.3.0.imag_conv.bias torch.Size([128])
# encoder.3.1.weight torch.Size([256])
# encoder.3.1.bias torch.Size([256])
# encoder.3.2.weight torch.Size([1])
# encoder.4.0.real_conv.weight torch.Size([128, 128, 5, 2])
# encoder.4.0.real_conv.bias torch.Size([128])
# encoder.4.0.imag_conv.weight torch.Size([128, 128, 5, 2])
# encoder.4.0.imag_conv.bias torch.Size([128])
# encoder.4.1.weight torch.Size([256])
# encoder.4.1.bias torch.Size([256])
# encoder.4.2.weight torch.Size([1])
# encoder.5.0.real_conv.weight torch.Size([128, 128, 5, 2])
# encoder.5.0.real_conv.bias torch.Size([128])
# encoder.5.0.imag_conv.weight torch.Size([128, 128, 5, 2])
# encoder.5.0.imag_conv.bias torch.Size([128])
# encoder.5.1.weight torch.Size([256])
# encoder.5.1.bias torch.Size([256])
# encoder.5.2.weight torch.Size([1])
# decoder.0.0.real_conv.weight torch.Size([256, 128, 5, 2])
# decoder.0.0.real_conv.bias torch.Size([128])
# decoder.0.0.imag_conv.weight torch.Size([256, 128, 5, 2])
# decoder.0.0.imag_conv.bias torch.Size([128])
# decoder.0.1.weight torch.Size([256])
# decoder.0.1.bias torch.Size([256])
# decoder.0.2.weight torch.Size([1])
# decoder.1.0.real_conv.weight torch.Size([256, 128, 5, 2])
# decoder.1.0.real_conv.bias torch.Size([128])
# decoder.1.0.imag_conv.weight torch.Size([256, 128, 5, 2])
# decoder.1.0.imag_conv.bias torch.Size([128])
# decoder.1.1.weight torch.Size([256])
# decoder.1.1.bias torch.Size([256])
# decoder.1.2.weight torch.Size([1])
# decoder.2.0.real_conv.weight torch.Size([256, 64, 5, 2])
# decoder.2.0.real_conv.bias torch.Size([64])
# decoder.2.0.imag_conv.weight torch.Size([256, 64, 5, 2])
# decoder.2.0.imag_conv.bias torch.Size([64])
# decoder.2.1.weight torch.Size([128])
# decoder.2.1.bias torch.Size([128])
# decoder.2.2.weight torch.Size([1])
# decoder.3.0.real_conv.weight torch.Size([128, 32, 5, 2])
# decoder.3.0.real_conv.bias torch.Size([32])
# decoder.3.0.imag_conv.weight torch.Size([128, 32, 5, 2])
# decoder.3.0.imag_conv.bias torch.Size([32])
# decoder.3.1.weight torch.Size([64])
# decoder.3.1.bias torch.Size([64])
# decoder.3.2.weight torch.Size([1])
# decoder.4.0.real_conv.weight torch.Size([64, 16, 5, 2])
# decoder.4.0.real_conv.bias torch.Size([16])
# decoder.4.0.imag_conv.weight torch.Size([64, 16, 5, 2])
# decoder.4.0.imag_conv.bias torch.Size([16])
# decoder.4.1.weight torch.Size([32])
# decoder.4.1.bias torch.Size([32])
# decoder.4.2.weight torch.Size([1])
# decoder.5.0.real_conv.weight torch.Size([32, 1, 5, 2])
# decoder.5.0.real_conv.bias torch.Size([1])
# decoder.5.0.imag_conv.weight torch.Size([32, 1, 5, 2])
# decoder.5.0.imag_conv.bias torch.Size([1])
# enhance.0.real_lstm.weight_ih_l0 torch.Size([512, 1536])
# enhance.0.real_lstm.weight_hh_l0 torch.Size([512, 128])
# enhance.0.real_lstm.bias_ih_l0 torch.Size([512])
# enhance.0.real_lstm.bias_hh_l0 torch.Size([512])
# enhance.0.imag_lstm.weight_ih_l0 torch.Size([512, 1536])
# enhance.0.imag_lstm.weight_hh_l0 torch.Size([512, 128])
# enhance.0.imag_lstm.bias_ih_l0 torch.Size([512])
# enhance.0.imag_lstm.bias_hh_l0 torch.Size([512])
# enhance.1.real_lstm.weight_ih_l0 torch.Size([512, 128])
# enhance.1.real_lstm.weight_hh_l0 torch.Size([512, 128])
# enhance.1.real_lstm.bias_ih_l0 torch.Size([512])
# enhance.1.real_lstm.bias_hh_l0 torch.Size([512])
# enhance.1.imag_lstm.weight_ih_l0 torch.Size([512, 128])
# enhance.1.imag_lstm.weight_hh_l0 torch.Size([512, 128])
# enhance.1.imag_lstm.bias_ih_l0 torch.Size([512])
# enhance.1.imag_lstm.bias_hh_l0 torch.Size([512])
# enhance.1.r_trans.weight torch.Size([1536, 128])
# enhance.1.r_trans.bias torch.Size([1536])
# enhance.1.i_trans.weight torch.Size([1536, 128])
# enhance.1.i_trans.bias torch.Size([1536])
# [*] Parameter Size: 4983821
# ==================================================================================================
# ✅ Model loaded successfully

# %%
def denoise_file(file_path):
    file_name = os.path.basename(file_path)

    if not os.path.isfile(file_path) or os.path.getsize(file_path) == 0:
        print(f"❌ Skipping invalid file: {file_path}")
        return None, None

    try:
        waveform, sr = torchaudio.load(file_path)
    except Exception as e:
        print(f"❌ torchaudio.load failed for {file_name}: {e}")
        return None, None

    if sr != sample_rate:
        print(f"⚠️ Skipping {file_name}: expected {sample_rate}Hz, got {sr}Hz")
        return None, None

    waveform = waveform.to(device)

    with torch.no_grad():
        _, enhanced = model(waveform)

    enhanced = enhanced.cpu()

    # ✅ Ensure shape is [1, T] and float32
    if enhanced.dim() == 1:
        enhanced = enhanced.unsqueeze(0)
    elif enhanced.dim() == 2 and enhanced.shape[0] > 1:
        pass
    elif enhanced.dim() == 2:
        enhanced = enhanced.squeeze(0).unsqueeze(0)

    enhanced = enhanced.clamp(-1.0, 1.0).to(torch.float32)

    # ✅ Save output
    out_path = os.path.join(output_dir, file_name)
    torchaudio.save(out_path, enhanced, sample_rate)

    return waveform.cpu(), enhanced

# %%
# 🎧 Play and compare a test file (e.g., file01.wav)
test_file = os.path.join(noisy_dir, "file1.wav")
noisy_audio, denoised_audio = denoise_file(test_file)

if noisy_audio is not None and denoised_audio is not None:
    print("🔊 Noisy Audio:")
    ipd.display(ipd.Audio(noisy_audio.numpy(), rate=sample_rate))

    print("🔉 Denoised Audio:")
    ipd.display(ipd.Audio(denoised_audio.numpy(), rate=sample_rate))
else:
    print("⚠️ Could not process test file.")
# Out:
# 🔊 Noisy Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 🔉 Denoised Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
